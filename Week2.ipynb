# %% [markdown]
# <a href="https://colab.research.google.com/github/atrinasalsabilnengkoda/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten1.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #BGR -> RGB channel conversion
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten1.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#save image file
#cv,imwrite('/content/drive/MyDrive/PCVK/Images/mandrill2.tiff',img5)

# show the plot with a larger canvas size
fig = plt.figure(figsize=(10,10)) # resize (10,10)
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Making shape

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# Pay attention to the coordinates of the points pt1 and pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2)) # value 2 to show that each point is made 3 channels representing R, G, and B
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Assigment

# %%
imgRGB = cv.resize(cv.imread('/content/drive/MyDrive/PCVK/Images/kitten1.jpg'), (200,125))
r,g,b = cv.split(imgRGB)
zeros=np.zeros(imgRGB.shape[:2],dtype='uint8')
red = cv2_imshow(cv.merge([r,zeros,zeros]))
green = cv2_imshow(cv.merge([zeros,g,zeros]))
blue = cv2_imshow(cv.merge([zeros,zeros,b]))
imgRG = cv2_imshow(cv.merge([r,g,zeros])) #Red-Green
imgGB = cv2_imshow(cv.merge([g,b,zeros])) #Green-Blue
# Out:
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F45EF814B90>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F45EF814310>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F45EF814B90>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F45EF814550>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F45EF814990>

# %%
cropImg = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cropImg = cropImg[10:100,10:100]

plt.imshow(cropImg)

# %%
croppedImg = img[5:30,0:500]

plt.imshow(croppedImg)

# %%
img7 = img3
cv.rectangle(img4,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(img4,pt1=(50,200),pt2=(200,150),color=(0,0,255),thickness=5)
cv.rectangle(img4,pt1=(700,500),pt2=(600,400),color=(255,0,0),thickness=-1)
cv.rectangle(img4,pt1=(300,450),pt2=(150,230),color=(255,0,255),thickness=7)
cv.rectangle(img4,pt1=(700,10),pt2=(650,90),color=(0,255,255),thickness=-1)
plt.imshow(img7)

# %%
img8 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(img8)

# %%
photo = cv.imread('/content/drive/MyDrive/PCVK/Images/photo.jpg')
photos = cv.cvtColor(photo,cv.COLOR_BGR2RGB)
cv.circle(photos,center=(325,630),radius=80,color=(255,0,0),thickness=10)
cv.rectangle(photos,pt1=(180,475),pt2=(480,775),color=(0,0,255),thickness=7)
plt.imshow(photos)

# %%
pict = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')
picts = cv.cvtColor(pict,cv.COLOR_BGR2RGB)
cv.rectangle(picts,pt1=(50,450),pt2=(100,500),color=(255,0,255),thickness=7)
plt.imshow(picts)

# %%
picts2 = picts
fonts = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(picts2,text='Kitten',org=(225,550),fontFace=font,fontScale=4,color=(200,150,255),thickness=5,lineType=cv.LINE_AA)
plt.imshow(picts2)
